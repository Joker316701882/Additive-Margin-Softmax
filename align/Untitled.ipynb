# %%
import os
from scipy import misc
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
names = os.listdir('./lfw-deepfunneled-crop-transf')

# %%
img1 = cv2.imread('cv2.jpg')#.astype(np.float32)
img2 = cv2.imread('misc.jpg')#.astype(np.float32)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9daea6b10340> in <module>()
# ----> 1 plt.imshow(img2)
#
# /home/ge_zheng/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3027                         filternorm=filternorm, filterrad=filterrad,
#    3028                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3029                         **kwargs)
#    3030     finally:
#    3031         ax.hold(washold)
#
# /home/ge_zheng/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# ...

# %%
plt.imshow(img1-img2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-db8bb907ab04> in <module>()
# ----> 1 plt.imshow(img1-img2)
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'

# %%
img1-img2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a9bd2eca3348> in <module>()
# ----> 1 img1-img2
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'

# %%
img = misc.imread('./AJ_Cook_0001.jpg')

# %%
misc.imsave('./misc.jpg',img.astype(np.uint8))

# %%
cv2.imwrite('./cv2.jpg',img[:,:,::-1])
# Out:
# True
