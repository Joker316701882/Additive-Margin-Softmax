# %%
import os
from scipy import misc
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
names = os.listdir('./lfw-deepfunneled-crop-transf')

# %%
img1 = misc.imread('./lfw-cropped/AJ_Cook/AJ_Cook_0001.jpg')#.astype(np.float32)
img2 = misc.imread('./lfw-deepfunneled-crop-transf/AJ_Cook/AJ_Cook_0001.jpg')#.astype(np.float32)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
plt.imshow(img1-img2)

# %%
img1-img2
# Out:
# array([[[  1, 255,   0],
#         [  0,   0,   0],
#         [  3,   1,   1],
#         ...,
#         [243, 247, 246],
#         [243, 248, 242],
#         [250, 255, 249]],
#
#        [[  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0, 254],
#         ...,
#         [239, 243, 242],
#         [239, 243, 240],
#         [249, 254, 248]],
#
#        [[  2,   0,   1],
#         [  1, 255, 254],
#         [  3,   1, 255],
#         ...,
#         [242, 246, 245],
#         [237, 241, 238],
#         [241, 246, 240]],
#
#        ...,
#        [[  5,   4,   2],
#         [ 13,  12,  12],
#         [ 11,  10,  10],
#         ...,
#         [ 13,  11,  14],
#         [ 15,  15,  16],
#         [ 10,  10,  11]],
#
#        [[  2,   1, 255],
#         [ 11,  10,   8],
#         [ 10,   9,   9],
#         ...,
#         [ 16,  14,  17],
#         [ 18,  16,  18],
#         [ 10,   8,  10]],
#
#        [[  4,   3,   1],
#         [ 11,  10,   8],
#         [  7,   6,   6],
# ...

# %%
img = misc.imread('./AJ_Cook_0001.jpg')
